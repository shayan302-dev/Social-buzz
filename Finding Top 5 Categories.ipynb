# %%
import pandas as pd
import numpy as np
df = pd.read_csv("DataFrame Ready For Analysis.csv")
df
# Out:
#        Unnamed: 0.1                            Content ID Reaction Type  \
# 0                 0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1                 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2                 2  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 3                 3  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 4                 4  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
# ...             ...                                   ...           ...
# 24568         24568  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike
# 24569         24569  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued
# 24570         24570  75d6b589-7fae-4a6d-b0d0-752845150e56    interested
# 24571         24571  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 24572         24572  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish
#
#                   Datetime Content Type    Category  Unnamed: 0 Sentiment  \
# ...

# %%
df.Category.unique()
# Out:
# array(['Studying', 'healthy eating', 'technology', 'food', 'cooking',
#        'dogs', 'soccer', 'public speaking', 'science', 'tennis', 'travel',
#        'fitness', 'education', 'studying', 'veganism', 'Animals',
#        'animals', 'culture', 'Fitness', 'Veganism', 'Travel', 'Education',
#        'Technology', 'Soccer', 'Culture', 'Food', 'Healthy Eating',
#        'Science', 'Public Speaking'], dtype=object)

# %%
sd = pd.DataFrame({"Unique Categories":['Studying', 'healthy eating', 'technology', 'food', 'cooking',
       'dogs', 'soccer', 'public speaking', 'science', 'tennis', 'travel',
       'fitness', 'education', 'studying', 'veganism', 'Animals',
       'animals', 'culture', 'Fitness', 'Veganism', 'Travel', 'Education',
       'Technology', 'Soccer', 'Culture', 'Food', 'Healthy Eating',
       'Science', 'Public Speaking']})

# %%
sd
# Out:
#    Unique Categories
# 0           Studying
# 1     healthy eating
# 2         technology
# 3               food
# 4            cooking
# 5               dogs
# 6             soccer
# 7    public speaking
# 8            science
# 9             tennis
# 10            travel
# 11           fitness
# 12         education
# 13          studying
# 14          veganism
# 15           Animals
# 16           animals
# 17           culture
# 18           Fitness
# 19          Veganism
# 20            Travel
# 21         Education
# 22        Technology
# 23            Soccer
# 24           Culture
# 25              Food
# 26    Healthy Eating
# 27           Science
# 28   Public Speaking

# %%
#sd.str.lower()

# %%
sd.drop_duplicates()
# Out:
#    Unique Categories
# 0           Studying
# 1     healthy eating
# 2         technology
# 3               food
# 4            cooking
# 5               dogs
# 6             soccer
# 7    public speaking
# 8            science
# 9             tennis
# 10            travel
# 11           fitness
# 12         education
# 13          studying
# 14          veganism
# 15           Animals
# 16           animals
# 17           culture
# 18           Fitness
# 19          Veganism
# 20            Travel
# 21         Education
# 22        Technology
# 23            Soccer
# 24           Culture
# 25              Food
# 26    Healthy Eating
# 27           Science
# 28   Public Speaking

# %%
df["Category"] = df["Category"].str.lower()

# %%
final = df.groupby('Category')['Score'].sum()

# %%
final.sort_values(ascending=False)
# Out:
# Category
# animals            74965
# science            71168
# healthy eating     69339
# technology         68738
# food               66676
# culture            66579
# travel             64880
# cooking            64756
# soccer             57783
# education          57436
# fitness            55323
# studying           54269
# dogs               52511
# tennis             50339
# veganism           49619
# public speaking    49264
# Name: Score, dtype: int64

# %%
final.to_csv("Top Categories.csv")
