# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Clean_Reaction.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                            Content ID  \
# 0             1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2             3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3             4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4             5           5  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#   Reaction Type             Datetime
# 0       disgust  2020-11-07 09:43:50
# 1       dislike  2021-06-17 12:22:51
# 2        scared  2021-04-18 05:13:58
# 3       disgust  2021-01-06 19:13:01
# 4    interested  2020-08-23 12:25:58

# %%
df1 = pd.read_csv("Clean_Content.csv")
df1.head()
# Out:
#    Unnamed: 0                            Content ID Content Type  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f        photo
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6        photo
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180        video
#
#          Category
# 0        Studying
# 1  healthy eating
# 2  healthy eating
# 3      technology
# 4            food

# %%
df2 = pd.merge(df,df1,on = "Content ID")

# %%
df2.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x                            Content ID  \
# 0             1             1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             2             2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2             3             3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3             4             4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4             5             5  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#   Reaction Type             Datetime  Unnamed: 0_y Content Type  Category
# 0       disgust  2020-11-07 09:43:50             0        photo  Studying
# 1       dislike  2021-06-17 12:22:51             0        photo  Studying
# 2        scared  2021-04-18 05:13:58             0        photo  Studying
# 3       disgust  2021-01-06 19:13:01             0        photo  Studying
# 4    interested  2020-08-23 12:25:58             0        photo  Studying

# %%
del df2["Unnamed: 0_y"]

# %%
del df2["Unnamed: 0_x"]

# %%
df2.head()
# Out:
#    Unnamed: 0.1                            Content ID Reaction Type  \
# 0             1  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1             2  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2             3  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 3             4  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 4             5  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
#
#               Datetime Content Type  Category
# 0  2020-11-07 09:43:50        photo  Studying
# 1  2021-06-17 12:22:51        photo  Studying
# 2  2021-04-18 05:13:58        photo  Studying
# 3  2021-01-06 19:13:01        photo  Studying
# 4  2020-08-23 12:25:58        photo  Studying

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0.1     0
# Content ID       0
# Reaction Type    0
# Datetime         0
# Content Type     0
# Category         0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24573 entries, 0 to 24572
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0.1   24573 non-null  int64
#  1   Content ID     24573 non-null  object
#  2   Reaction Type  24573 non-null  object
#  3   Datetime       24573 non-null  object
#  4   Content Type   24573 non-null  object
#  5   Category       24573 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 1.1+ MB

# %%
del df2["Unnamed: 0.1"]

# %%
df2
# Out:
#                                  Content ID Reaction Type  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
# ...                                     ...           ...
# 24568  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike
# 24569  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued
# 24570  75d6b589-7fae-4a6d-b0d0-752845150e56    interested
# 24571  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 24572  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish
#
#                   Datetime Content Type    Category
# 0      2020-11-07 09:43:50        photo    Studying
# 1      2021-06-17 12:22:51        photo    Studying
# 2      2021-04-18 05:13:58        photo    Studying
# 3      2021-01-06 19:13:01        photo    Studying
# ...

# %% [markdown]
# #### Changing Order of Column

# %%
#new_order_columns = ["Content ID","Reaction Type","Datetime","Content Type","Category"]
#df2 = df2[new_order_columns]

# %%
df2.head()
# Out:
#                              Content ID Reaction Type             Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2020-11-07 09:43:50
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  2021-06-17 12:22:51
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared  2021-04-18 05:13:58
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2021-01-06 19:13:01
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested  2020-08-23 12:25:58
#
#   Content Type  Category
# 0        photo  Studying
# 1        photo  Studying
# 2        photo  Studying
# 3        photo  Studying
# 4        photo  Studying

# %%
df0 = pd.read_csv("ReactionTypes.csv")
df0.head()
# Out:
#    Unnamed: 0        Type Sentiment  Score
# 0           0       heart  positive     60
# 1           1        want  positive     70
# 2           2     disgust  negative      0
# 3           3        hate  negative      5
# 4           4  interested  positive     30

# %%
df0 = df0.rename(columns = {"Type" : "Reaction Type"})
df0.head()
# Out:
#    Unnamed: 0 Reaction Type Sentiment  Score
# 0           0         heart  positive     60
# 1           1          want  positive     70
# 2           2       disgust  negative      0
# 3           3          hate  negative      5
# 4           4    interested  positive     30

# %%
df4 = pd.merge(df2,df0,on = "Reaction Type")

# %%
df4.head(10)
# Out:
#                              Content ID Reaction Type             Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2020-11-07 09:43:50
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  2021-06-17 12:22:51
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared  2021-04-18 05:13:58
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2021-01-06 19:13:01
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested  2020-08-23 12:25:58
# 5  97522e57-d9ab-4bd6-97bf-c24d952602d2       peeking  2020-12-07 06:27:54
# 6  97522e57-d9ab-4bd6-97bf-c24d952602d2       cherish  2021-04-11 17:35:49
# 7  97522e57-d9ab-4bd6-97bf-c24d952602d2          hate  2021-01-27 08:32:09
# 8  97522e57-d9ab-4bd6-97bf-c24d952602d2       peeking  2021-04-01 22:54:23
# 9  97522e57-d9ab-4bd6-97bf-c24d952602d2          love  2020-08-04 05:05:02
#
#   Content Type  Category  Unnamed: 0 Sentiment  Score
# 0        photo  Studying           2  negative      0
# ...

# %%
df4.to_csv("DataFrame Ready For Analysis.csv")
